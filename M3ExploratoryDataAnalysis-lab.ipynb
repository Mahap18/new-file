# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="380" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify the distribution of data in the dataset.
#
# -   Identify outliers in the dataset.
#
# -   Remove outliers from the dataset.
#
# -   Identify correlation between features in the dataset.

# %% [markdown]
# * * *

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd
# Out:
# <ipython-input-1-7dd3504c366f>:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %% [markdown]
# The functions below will download the dataset into your browser:

# %%
from pyodide.http import pyfetch

async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# %%
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv"

# %% [markdown]
# To obtain the dataset, utilize the download() function as defined above:

# %%
await download(file_path, "m2_survey_data.csv")
file_name="m2_survey_data.csv"

# %% [markdown]
# Utilize the Pandas method read_csv() to load the data into a dataframe.

# %%
df = pd.read_csv(file_name)

# %% [markdown]
# > Note: This version of the lab is working on JupyterLite, which requires the dataset to be downloaded to the interface.While working on the downloaded version of this notebook on their local machines(Jupyter Anaconda), the learners can simply **skip the steps above,** and simply use the URL directly in the `pandas.read_csv()` function. You can uncomment and run the statements in the cell below.

# %%
#df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
from pyodide.http import pyfetch
import pandas as pd
import matplotlib.pyplot as plt

# Function to download the file
async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# File path for the CSV file
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv"

# Download the file
await download(file_path, "m2_survey_data.csv")

# Load the CSV data into a DataFrame
df = pd.read_csv("m2_survey_data.csv")

# Check if the 'ConvertedComp' column exists and plot the histogram
if 'ConvertedComp' in df.columns:
    # Plotting the histogram using matplotlib
    plt.figure(figsize=(10,6))
    plt.hist(df['ConvertedComp'].dropna(), bins=30, color='blue', edgecolor='black', alpha=0.7)
    plt.title('Histogram of Converted Annual Salary (ConvertedComp)', fontsize=14)
    plt.xlabel('Annual Salary (USD)', fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
    plt.grid(True)
    plt.show()
else:
    print("Column 'ConvertedComp' not found in the data.")

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
from pyodide.http import pyfetch
import pandas as pd
import matplotlib.pyplot as plt

# Function to download the file
async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# File path for the CSV file
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv"

# Download the file
await download(file_path, "m2_survey_data.csv")

# Load the CSV data into a DataFrame
df = pd.read_csv("m2_survey_data.csv")

# Check if the 'ConvertedComp' column exists and plot the histogram
if 'ConvertedComp' in df.columns:
    # Plotting the histogram using matplotlib
    plt.figure(figsize=(10,6))
    plt.hist(df['ConvertedComp'].dropna(), bins=30, color='blue', edgecolor='black', alpha=0.7)
    plt.title('Histogram of Converted Annual Salary (ConvertedComp)', fontsize=14)
    plt.xlabel('Annual Salary (USD)', fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
    plt.grid(True)
    plt.show()
else:
    print("Column 'ConvertedComp' not found in the data.")

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
from pyodide.http import pyfetch
import pandas as pd

# Function to download the file
async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# File path for the CSV file
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv"

# Download the file
await download(file_path, "m2_survey_data.csv")

# Load the CSV data into a DataFrame
df = pd.read_csv("m2_survey_data.csv")

# Check if the 'ConvertedComp' column exists and calculate the median
if 'ConvertedComp' in df.columns:
    # Calculate the median of the 'ConvertedComp' column
    median_value = df['ConvertedComp'].median()
    print(f"The median of the 'ConvertedComp' column is: {median_value}")
else:
    print("Column 'ConvertedComp' not found in the data.")
# Out:
# The median of the 'ConvertedComp' column is: 57745.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
from pyodide.http import pyfetch
import pandas as pd

# Function to download the file
async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# File path for the CSV file
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv"

# Download the file
await download(file_path, "m2_survey_data.csv")

# Load the CSV data into a DataFrame
df = pd.read_csv("m2_survey_data.csv")

# Check if the 'Gender' column exists and count the number of 'Man' responses
if 'Gender' in df.columns:
    # Count the number of responders who identified as 'Man'
    man_count = df[df['Gender'] == 'Man'].shape[0]
    print(f"The number of responders who identified as 'Man' is: {man_count}")
else:
    print("Column 'Gender' not found in the data.")
# Out:
# The number of responders who identified as 'Man' is: 10480

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
from pyodide.http import pyfetch
import pandas as pd

# Function to download the file
async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# File path for the CSV file
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv"

# Download the file
await download(file_path, "m2_survey_data.csv")

# Load the CSV data into a DataFrame
df = pd.read_csv("m2_survey_data.csv")

# Check if the 'Gender' and 'ConvertedComp' columns exist and calculate the median for 'Woman'
if 'Gender' in df.columns and 'ConvertedComp' in df.columns:
    # Filter the data for responders who identified as 'Woman'
    woman_data = df[df['Gender'] == 'Woman']
    
    # Calculate the median of 'ConvertedComp' for these responders
    median_woman = woman_data['ConvertedComp'].median()
    print(f"The median of 'ConvertedComp' for responders identified as 'Woman' is: {median_woman}")
else:
    print("Column 'Gender' or 'ConvertedComp' not found in the data.")
# Out:
# The median of 'ConvertedComp' for responders identified as 'Woman' is: 57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
from pyodide.http import pyfetch
import pandas as pd

# Function to download the file
async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# File path for the CSV file
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv"

# Download the file
await download(file_path, "m2_survey_data.csv")

# Load the CSV data into a DataFrame
df = pd.read_csv("m2_survey_data.csv")

# Check if the 'Age' column exists and calculate the five-number summary
if 'Age' in df.columns:
    # Five-number summary using pandas describe method
    five_number_summary = df['Age'].describe(percentiles=[.25, .5, .75])
    print(five_number_summary)
else:
    print("Column 'Age' not found in the data.")
# Out:
# count    11111.000000
# mean        30.778895
# std          7.393686
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
from pyodide.http import pyfetch
import pandas as pd
import matplotlib.pyplot as plt

# Function to download the file
async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# File path for the CSV file
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv"

# Download the file
await download(file_path, "m2_survey_data.csv")

# Load the CSV data into a DataFrame
df = pd.read_csv("m2_survey_data.csv")

# Check if the 'Age' column exists and plot the histogram
if 'Age' in df.columns:
    # Plotting the histogram using matplotlib
    plt.figure(figsize=(10,6))
    plt.hist(df['Age'].dropna(), bins=20, color='green', edgecolor='black', alpha=0.7)
    plt.title('Histogram of Age', fontsize=14)
    plt.xlabel('Age', fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
    plt.grid(True)
    plt.show()
else:
    print("Column 'Age' not found in the data.")

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
from pyodide.http import pyfetch
import pandas as pd
import matplotlib.pyplot as plt

# Function to download the file
async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# File path for the CSV file
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv"

# Download the file
await download(file_path, "m2_survey_data.csv")

# Load the CSV data into a DataFrame
df = pd.read_csv("m2_survey_data.csv")

# Check if the 'ConvertedComp' column exists and plot the box plot
if 'ConvertedComp' in df.columns:
    # Plotting the box plot using matplotlib
    plt.figure(figsize=(10,6))
    plt.boxplot(df['ConvertedComp'].dropna(), vert=False)
    plt.title('Box Plot of Converted Annual Salary (ConvertedComp)', fontsize=14)
    plt.xlabel('Annual Salary (USD)', fontsize=12)
    plt.grid(True)
    plt.show()
else:
    print("Column 'ConvertedComp' not found in the data.")

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
from pyodide.http import pyfetch
import pandas as pd

# Function to download the file
async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# File path for the CSV file
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv"

# Download the file
await download(file_path, "m2_survey_data.csv")

# Load the CSV data into a DataFrame
df = pd.read_csv("m2_survey_data.csv")

# Check if the 'ConvertedComp' column exists and calculate the IQR
if 'ConvertedComp' in df.columns:
    # Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = df['ConvertedComp'].quantile(0.25)
    Q3 = df['ConvertedComp'].quantile(0.75)
    
    # Calculate the IQR
    IQR = Q3 - Q1
    print(f"The Interquartile Range (IQR) for 'ConvertedComp' is: {IQR}")
else:
    print("Column 'ConvertedComp' not found in the data.")
# Out:
# The Interquartile Range (IQR) for 'ConvertedComp' is: 73132.0

# %% [markdown]
# Find out the upper and lower bounds.

# %%
from pyodide.http import pyfetch
import pandas as pd

# Function to download the file
async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# File path for the CSV file
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv"

# Download the file
await download(file_path, "m2_survey_data.csv")

# Load the CSV data into a DataFrame
df = pd.read_csv("m2_survey_data.csv")

# Check if the 'ConvertedComp' column exists and calculate the bounds
if 'ConvertedComp' in df.columns:
    # Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = df['ConvertedComp'].quantile(0.25)
    Q3 = df['ConvertedComp'].quantile(0.75)
    
    # Calculate the IQR
    IQR = Q3 - Q1
    
    # Calculate the lower and upper bounds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    print(f"Lower Bound: {lower_bound}")
    print(f"Upper Bound: {upper_bound}")
else:
    print("Column 'ConvertedComp' not found in the data.")
# Out:
# Lower Bound: -82830.0
# Upper Bound: 209698.0

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
from pyodide.http import pyfetch
import pandas as pd

# Function to download the file
async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# File path for the CSV file
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv"

# Download the file
await download(file_path, "m2_survey_data.csv")

# Load the CSV data into a DataFrame
df = pd.read_csv("m2_survey_data.csv")

# Check if the 'ConvertedComp' column exists and identify the outliers
if 'ConvertedComp' in df.columns:
    # Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = df['ConvertedComp'].quantile(0.25)
    Q3 = df['ConvertedComp'].quantile(0.75)
    
    # Calculate the IQR
    IQR = Q3 - Q1
    
    # Calculate the lower and upper bounds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Identify outliers: values below the lower bound or above the upper bound
    outliers = df[(df['ConvertedComp'] < lower_bound) | (df['ConvertedComp'] > upper_bound)]
    
    # Count the number of outliers
    num_outliers = outliers.shape[0]
    
    print(f"The number of outliers in 'ConvertedComp' is: {num_outliers}")
else:
    print("Column 'ConvertedComp' not found in the data.")
# Out:
# The number of outliers in 'ConvertedComp' is: 879

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
from pyodide.http import pyfetch
import pandas as pd

# Function to download the file
async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# File path for the CSV file
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv"

# Download the file
await download(file_path, "m2_survey_data.csv")

# Load the CSV data into a DataFrame
df = pd.read_csv("m2_survey_data.csv")

# Check if the 'ConvertedComp' column exists and remove the outliers
if 'ConvertedComp' in df.columns:
    # Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = df['ConvertedComp'].quantile(0.25)
    Q3 = df['ConvertedComp'].quantile(0.75)
    
    # Calculate the IQR
    IQR = Q3 - Q1
    
    # Calculate the lower and upper bounds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Create a new DataFrame by removing the outliers
    df_no_outliers = df[(df['ConvertedComp'] >= lower_bound) & (df['ConvertedComp'] <= upper_bound)]
    
    # Check the shape of the new DataFrame
    print(f"Original DataFrame shape: {df.shape}")
    print(f"New DataFrame shape (after removing outliers): {df_no_outliers.shape}")
else:
    print("Column 'ConvertedComp' not found in the data.")
# Out:
# Original DataFrame shape: (11398, 85)
# New DataFrame shape (after removing outliers): (9703, 85)

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
from pyodide.http import pyfetch
import pandas as pd

# Function to download the file
async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# File path for the CSV file
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv"

# Download the file
await download(file_path, "m2_survey_data.csv")

# Load the CSV data into a DataFrame
df = pd.read_csv("m2_survey_data.csv")

# Check if 'Age' column exists and find correlations with other numerical columns
if 'Age' in df.columns:
    # Select only numerical columns
    numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns
    
    # Calculate the correlation of 'Age' with all other numerical columns
    correlation_with_age = df[numerical_columns].corr()['Age'].drop('Age')  # Drop 'Age' itself from the results
    
    # Display the correlation values
    print("Correlation of 'Age' with other numerical columns:")
    print(correlation_with_age)
else:
    print("Column 'Age' not found in the data.")

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).

# %% [markdown]
# <!--## Change Log

# %% [markdown]
# <!--| Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |--!>
